# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('4110008001_databaseLoadingData.csv')
data.head()
# Out:
#    REF_DATE     GEO           DGUID                    Indigenous identity  \
# 0      2022  Canada  2021A000011124  First Nations (North American Indian)
# 1      2022  Canada  2021A000011124  First Nations (North American Indian)
# 2      2022  Canada  2021A000011124  First Nations (North American Indian)
# 3      2022  Canada  2021A000011124  First Nations (North American Indian)
# 4      2022  Canada  2021A000011124  First Nations (North American Indian)
#
#         Age group Gender                                     Overall health  \
# 0  15 to 24 years   Men+  Self-perceived general health, excellent or ve...
# 1  15 to 24 years   Men+  Self-perceived general health, excellent or ve...
# 2  15 to 24 years   Men+  Self-perceived general health, excellent or ve...
# 3  15 to 24 years   Men+  Self-perceived general health, excellent or ve...
# 4  15 to 24 years   Men+  Self-perceived general health, excellent or ve...
#
#           Housing - Needs repairs  \
# 0  Total, housing - Needs repairs
# 1  Total, housing - Needs repairs
# 2  Total, housing - Needs repairs
# 3  Total, housing - Needs repairs
# 4  Total, housing - Needs repairs
#
#                         Persons per room (crowding)  \
# 0                      One person or fewer per room
# 1                      One person or fewer per room
# 2                      One person or fewer per room
# 3                      One person or fewer per room
# 4  More than one but less than 1.5 persons per room
#
#                      Statistics  ... UOM_ID  SCALAR_FACTOR SCALAR_ID  \
# 0             Number of persons  ...    249          units         0
# 1                       Percent  ...    239          units         0
# 2   Low 95% confidence interval  ...    239          units         0
# 3  High 95% confidence interval  ...    239          units         0
# 4             Number of persons  ...    249          units         0
#
#         VECTOR       COORDINATE    VALUE  STATUS SYMBOL  TERMINATED  DECIMALS
# 0  v1602021051  1.2.2.2.2.1.2.1  24480.0     NaN    NaN         NaN         0
# 1  v1602021052  1.2.2.2.2.1.2.2     90.2     NaN    NaN         NaN         1
# 2  v1602021053  1.2.2.2.2.1.2.3     86.0     NaN    NaN         NaN         1
# 3  v1602021054  1.2.2.2.2.1.2.4     93.3     NaN    NaN         NaN         1
# 4  v1602021055  1.2.2.2.2.1.3.1      NaN       F    NaN         NaN         0
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9216 entries, 0 to 9215
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   REF_DATE                     9216 non-null   int64
#  1   GEO                          9216 non-null   str
#  2   DGUID                        9216 non-null   str
#  3   Indigenous identity          9216 non-null   str
#  4   Age group                    9216 non-null   str
#  5   Gender                       9216 non-null   str
#  6   Overall health               9216 non-null   str
#  7   Housing - Needs repairs      9216 non-null   str
#  8   Persons per room (crowding)  9216 non-null   str
#  9   Statistics                   9216 non-null   str
#  10  UOM                          9216 non-null   str
#  11  UOM_ID                       9216 non-null   int64
#  12  SCALAR_FACTOR                9216 non-null   str
#  13  SCALAR_ID                    9216 non-null   int64
#  14  VECTOR                       9216 non-null   str
#  15  COORDINATE                   9216 non-null   str
#  16  VALUE                        2233 non-null   float64
#  17  STATUS                       7373 non-null   str
#  18  SYMBOL                       0 non-null      float64
#  19  TERMINATED                   0 non-null      float64
#  20  DECIMALS                     9216 non-null   int64
# dtypes: float64(3), int64(4), str(14)
# memory usage: 1.5 MB

# %%
data.shape
# Out:
# (9216, 21)

# %%
data.count()
# Out:
# REF_DATE                       9216
# GEO                            9216
# DGUID                          9216
# Indigenous identity            9216
# Age group                      9216
# Gender                         9216
# Overall health                 9216
# Housing - Needs repairs        9216
# Persons per room (crowding)    9216
# Statistics                     9216
# UOM                            9216
# UOM_ID                         9216
# SCALAR_FACTOR                  9216
# SCALAR_ID                      9216
# VECTOR                         9216
# COORDINATE                     9216
# VALUE                          2233
# STATUS                         7373
# SYMBOL                            0
# TERMINATED                        0
# DECIMALS                       9216
# dtype: int64

# %%
sns.heatmap(data.isna(), cmap='Blues')
# Out:
# <Axes: >

# %%
# F means they are too unreliable to be published
data.loc[data['VALUE'].isnull(),:]['STATUS'].value_counts()
# Out:
# STATUS
# F    6983
# Name: count, dtype: int64

# %%
data = data.drop(["TERMINATED", "SYMBOL", "DECIMALS", "SCALAR_ID", "SCALAR_FACTOR", "DGUID", "GEO", "REF_DATE"], axis=1)

# %%
data = data.loc[data['Statistics'] == "Number of persons", :]

# %%
data = data.loc[data['Indigenous identity'] != "Indigenous responses not included elsewhere"]

# %%
data.head()
# Out:
#                       Indigenous identity       Age group Gender  \
# 0   First Nations (North American Indian)  15 to 24 years   Men+
# 4   First Nations (North American Indian)  15 to 24 years   Men+
# 8   First Nations (North American Indian)  15 to 24 years   Men+
# 12  First Nations (North American Indian)  15 to 24 years   Men+
# 16  First Nations (North American Indian)  15 to 24 years   Men+
#
#                                        Overall health  \
# 0   Self-perceived general health, excellent or ve...
# 4   Self-perceived general health, excellent or ve...
# 8   Self-perceived general health, excellent or ve...
# 12  Self-perceived general health, excellent or ve...
# 16  Self-perceived general health, excellent or ve...
#
#                    Housing - Needs repairs  \
# 0           Total, housing - Needs repairs
# 4           Total, housing - Needs repairs
# 8           Total, housing - Needs repairs
# 12  No, only regular maintenance is needed
# 16  No, only regular maintenance is needed
#
#                          Persons per room (crowding)         Statistics  \
# 0                       One person or fewer per room  Number of persons
# 4   More than one but less than 1.5 persons per room  Number of persons
# 8                       1.5 persons or more per room  Number of persons
# 12                      One person or fewer per room  Number of persons
# 16  More than one but less than 1.5 persons per room  Number of persons
#
#         UOM  UOM_ID       VECTOR       COORDINATE    VALUE STATUS
# 0   Persons     249  v1602021051  1.2.2.2.2.1.2.1  24480.0    NaN
# 4   Persons     249  v1602021055  1.2.2.2.2.1.3.1      NaN      F
# 8   Persons     249  v1602021059  1.2.2.2.2.1.4.1      NaN      F
# 12  Persons     249  v1602021071  1.2.2.2.2.2.2.1  17730.0    NaN
# 16  Persons     249  v1602021075  1.2.2.2.2.2.3.1      NaN      F

# %%
filter = data['STATUS'].str.startswith('E')

df = data.loc[filter, ['COORDINATE', 'VALUE']].copy()

# extract prefix and last index
df[['prefix','idx']] = df['COORDINATE'].str.extract(
    r'(?P<prefix>(?:[0-9]+\.){7})(?P<idx>[0-9])'
)

df['idx'] = df['idx'].astype(int)

# pivot so we get columns 1,2,3,4
wide = df.pivot(index='prefix', columns='idx', values='VALUE')

wide.head()
# Out:
# idx                   1
# prefix
# 1.2.2.2.12.3.2.  3810.0
# 1.2.2.2.13.3.2.  4550.0
# 1.2.2.2.2.3.2.   5200.0
# 1.2.2.2.5.3.2.   4710.0
# 1.2.2.2.6.2.2.   3570.0

# %%
# apply condition: a[X.3] <= a[X.2] <= a[X.4]
mask = (wide[3] <= wide[2]) & (wide[2] <= wide[4])

# return X.1 coordinates
result = (wide.loc[mask]
          .index
          .to_series()
          .str.cat(['1'] * mask.sum()))

# %%
data['STATUS'].value_counts()
# Out:
# STATUS
# F    1400
# E     146
# Name: count, dtype: int64

# %%
# data['REF_DATE'].value_counts()
# only data is present for 2022 year

# %%
# data['GEO'].value_counts()
# only data present for Indigenous population in Canada

# %%
data['Indigenous identity'].value_counts()
# Out:
# Indigenous identity
# First Nations (North American Indian)    576
# Métis                                    576
# Inuk (Inuit)                             576
# Name: count, dtype: int64

# %%
data['Statistics'].value_counts()
# Out:
# Statistics
# Number of persons    1728
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data, x="Indigenous identity", y="VALUE")
plt.title("Distribution")
plt.tight_layout()
plt.show()

# %%
sns.barplot(data, x="Indigenous identity", y="VALUE", hue="Gender")
# Out:
# <Axes: xlabel='Indigenous identity', ylabel='VALUE'>

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data, x="Indigenous identity", y="VALUE", hue="Overall health")
# Out:
# <Axes: xlabel='Indigenous identity', ylabel='VALUE'>

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data, x="Indigenous identity", y="VALUE", hue="Age group")
# Out:
# <Axes: xlabel='Indigenous identity', ylabel='VALUE'>

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data, x="Indigenous identity", y="VALUE", hue="Housing - Needs repairs")
# Out:
# <Axes: xlabel='Indigenous identity', ylabel='VALUE'>

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data, x="Indigenous identity", y="VALUE", hue="Persons per room (crowding)")
# Out:
# <Axes: xlabel='Indigenous identity', ylabel='VALUE'>
